# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')
df.head(10)
# Out:
#    LoanNr_ChkDgt                            Name            City State    Zip  \
# 0     1000014003                  ABC HOBBYCRAFT      EVANSVILLE    IN  47711
# 1     1000024006     LANDMARK BAR & GRILLE (THE)       NEW PARIS    IN  46526
# 2     1000034009           WHITLOCK DDS, TODD M.     BLOOMINGTON    IN  47401
# 3     1000044001   BIG BUCKS PAWN & JEWELRY, LLC    BROKEN ARROW    OK  74012
# 4     1000054004     ANASTASIA CONFECTIONS, INC.         ORLANDO    FL  32801
# 5     1000084002  B&T SCREW MACHINE COMPANY, INC      PLAINVILLE    CT   6062
# 6     1000093009   MIDDLE ATLANTIC SPORTS CO INC           UNION    NJ   7083
# 7     1000094005                 WEAVER PRODUCTS     SUMMERFIELD    FL  34491
# 8     1000104006                TURTLE BEACH INN  PORT SAINT JOE    FL  32456
# 9     1000124001         INTEXT BUILDING SYS LLC     GLASTONBURY    CT   6073
#
#                             Bank BankState   NAICS ApprovalDate  ApprovalFY  \
# ...

# %%
df.head(1).to_json()
# Out:
# '{"LoanNr_ChkDgt":{"0":1000014003},"Name":{"0":"ABC HOBBYCRAFT"},"City":{"0":"EVANSVILLE"},"State":{"0":"IN"},"Zip":{"0":47711},"Bank":{"0":"FIFTH THIRD BANK"},"BankState":{"0":"OH"},"NAICS":{"0":451120},"ApprovalDate":{"0":"1997-02-28"},"ApprovalFY":{"0":1997},"Term":{"0":84},"NoEmp":{"0":4},"NewExist":{"0":2.0},"CreateJob":{"0":0},"RetainedJob":{"0":0},"FranchiseCode":{"0":1},"UrbanRural":{"0":0},"RevLineCr":{"0":"N"},"LowDoc":{"0":"Y"},"ChgOffDate":{"0":null},"DisbursementDate":{"0":"28-Feb-99"},"DisbursementGross":{"0":60000.0},"BalanceGross":{"0":0.0},"MIS_Status":{"0":"P I F"},"ChgOffPrinGr":{"0":"$0.00 "},"GrAppv":{"0":"$60,000.00 "},"SBA_Appv":{"0":"$48,000.00 "},"cat_activites":{"0":45},"SBA_loan_float":{"0":48000.0},"bank_loan_float":{"0":60000.0},"crisis":{"0":0}}'

# %%
df_10 = df.head(10)
df_10.to_csv('dataset_10.csv', index=False)
